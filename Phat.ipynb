# %% [markdown]
# <a href="https://colab.research.google.com/github/thanakppm/Project_Python_Retail_Store_Group_4/blob/Phatchariya_Phunontha_683020589-0/Phat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Phatchariya"
print(type(name))
# Out:
# <class 'str'>
