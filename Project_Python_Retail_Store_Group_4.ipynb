# %% [markdown]
# <a href="https://colab.research.google.com/github/thanakppm/Project-Python/blob/main/Project_Python_Retail_Store_Group_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Project Python Retail Store Group 4
