# %% [markdown]
# <a href="https://colab.research.google.com/github/thanakppm/Project_Python_Retail_Store_Group_4/blob/Thanakorn_Phongphet_683020572-7/RS_May.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Project Python Retail Store Group 4 (ส่วนตัว ธนากร พงษ์เพชร 683020572-7)

# %%
print("May")
# Out:
# May
