# %% [markdown]
# <a href="https://colab.research.google.com/github/thanakppm/Project-Python/blob/main/May.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Project Python

# %%
print("TT")
# Out:
# TT
